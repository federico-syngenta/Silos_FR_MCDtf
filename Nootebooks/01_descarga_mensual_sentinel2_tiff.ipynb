# %%
import sys, torch, torchvision, rasterio, geopandas
print("Python     ", sys.version.split()[0])
print("PyTorch    ", torch.__version__)
print("torchvision", torchvision.__version__)
print("rasterio   ", rasterio.__version__)
print("GDAL       ", rasterio.__gdal_version__)
print("GeoPandas  ", geopandas.__version__)
# Out:
# Python      3.13.3
# PyTorch     2.8.0+cpu
# torchvision 0.23.0+cpu
# rasterio    1.4.3
# GDAL        3.9.3
# GeoPandas   1.1.1

# %% [markdown]
# # NOOTEBOOK DESCARGA DE IMAGENES

# %% [markdown]
# ## Aqui encontraran dos formas/tecnicas de descarga de imagenes Sentinel S2A
#
# 1- SentinelHub
# 2- Public AWS bucket

# %%
###

# %% [markdown]
# ### SentinelHub

# %%
#Doc https://documentation.dataspace.copernicus.eu/notebook-samples/sentinelhub/introduction_to_SH_APIs.html
#API KEY : https://shapps.dataspace.copernicus.eu/dashboard/#/

# %%
#pip install sentinelhub

# %%
# Utilities
import matplotlib.pyplot as plt
import pandas as pd
import getpass

from sentinelhub import (
    SHConfig,
    DataCollection,
    SentinelHubCatalog,
    SentinelHubRequest,
    SentinelHubStatistical,
    BBox,
    bbox_to_dimensions,
    CRS,
    MimeType,
    Geometry,
)

#from utils import plot_image

# %%
from dotenv import load_dotenv
import os

# Carga las variables del archivo .env (en el directorio raíz del proyecto)
load_dotenv(dotenv_path='../.env')  # Ajusta la ruta si tu notebook está en una subcarpeta

client_id = os.environ.get('CDSE_CLIENT_ID')
client_secret = os.environ.get('CDSE_CLIENT_SECRET')

# %%
# Only run this cell if you have not created a configuration.

config = SHConfig()
config.sh_client_id = client_id
config.sh_client_secret = client_secret
config.sh_token_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
config.sh_base_url = "https://sh.dataspace.copernicus.eu"
config.save("cdse")

# %%
# Definir el área de interés (AOI) con 4 puntos de lat/lon
lon_min = -63.95
lat_min = -31.75
lon_max = -63.75
lat_max = -31.60

aoi_coords_wgs84 = [lon_min, lat_min, lon_max, lat_max]

# %%
resolution = 10
aoi_bbox = BBox(bbox=aoi_coords_wgs84, crs=CRS.WGS84)
aoi_size = bbox_to_dimensions(aoi_bbox, resolution=resolution)

print(f"Image shape at {resolution} m resolution: {aoi_size} pixels")
# Out:
# Image shape at 10 m resolution: (1883, 1677) pixels

# %%
catalog = SentinelHubCatalog(config=config)
catalog

# %%
aoi_bbox = BBox(bbox=aoi_coords_wgs84, crs=CRS.WGS84)
time_interval = "2025-07-01", "2025-07-20"

search_iterator = catalog.search(
    DataCollection.SENTINEL2_L2A,
    bbox=aoi_bbox,
    time=time_interval,
    fields={"include": ["id", "properties.datetime"], "exclude": []},
)

results = list(search_iterator)
print("Total number of results:", len(results))

results
# Out:
# Total number of results: 10
# [{'id': 'S2A_MSIL2A_20250719T141111_N0511_R110_T20HMK_20250719T211521.SAFE',
#   'properties': {'datetime': '2025-07-19T14:21:58.521Z'}},
#  {'id': 'S2A_MSIL2A_20250719T141111_N0511_R110_T20JML_20250719T211521.SAFE',
#   'properties': {'datetime': '2025-07-19T14:21:44.092Z'}},
#  {'id': 'S2C_MSIL2A_20250717T141111_N0511_R110_T20HMK_20250717T173322.SAFE',
#   'properties': {'datetime': '2025-07-17T14:22:02.422Z'}},
#  {'id': 'S2C_MSIL2A_20250717T141111_N0511_R110_T20JML_20250717T173322.SAFE',
#   'properties': {'datetime': '2025-07-17T14:21:47.995Z'}},
#  {'id': 'S2B_MSIL2A_20250712T140709_N0511_R110_T20HMK_20250712T173831.SAFE',
#   'properties': {'datetime': '2025-07-12T14:21:42.721Z'}},
#  {'id': 'S2B_MSIL2A_20250712T140709_N0511_R110_T20JML_20250712T173831.SAFE',
#   'properties': {'datetime': '2025-07-12T14:21:28.273Z'}},
#  {'id': 'S2C_MSIL2A_20250707T141111_N0511_R110_T20HMK_20250707T191716.SAFE',
#   'properties': {'datetime': '2025-07-07T14:22:01.949Z'}},
#  {'id': 'S2C_MSIL2A_20250707T141111_N0511_R110_T20JML_20250707T191716.SAFE',
#   'properties': {'datetime': '2025-07-07T14:21:47.516Z'}},
#  {'id': 'S2B_MSIL2A_20250702T140709_N0511_R110_T20HMK_20250702T175025.SAFE',
#   'properties': {'datetime': '2025-07-02T14:21:42.262Z'}},
#  {'id': 'S2B_MSIL2A_20250702T140709_N0511_R110_T20JML_20250702T175025.SAFE',
#   'properties': {'datetime': '2025-07-02T14:21:27.817Z'}}]

# %%
#!/usr/bin/env python3
"""
Descarga robusta de tiles completos Sentinel-2 (L2A) desde Copernicus Data Space (ODATA).
Incluye filtro por plataforma (ej: 'S2A') + post-filtrado por fecha de sensado extraída del NAME.
"""

import os
import re
import zipfile
import glob
import shutil
from pathlib import Path
from datetime import datetime, date
import requests
import rasterio
import numpy as np

# ----------------------
# CONFIGURACIÓN (modifica aquí)
# ----------------------
CLIENT_ID = os.environ.get("CDSE_CLIENT_ID", client_id)
CLIENT_SECRET = os.environ.get("CDSE_CLIENT_SECRET", client_secret)

#AOI = [-63.95, -31.75, -63.75, -31.6]
AOI = [-62.16, -32.75, -62.04, -32.64] #marcos juarez
#aoi_coords = [(-62.6, -33.6), (-61.6, -33.6), (-61.6, -32.4), (-62.6, -32.4)]
START_DATE = "2022-06-01"
END_DATE   = "2022-06-30"
MAX_CLOUD_COVER = 20
MAX_PRODUCTS_TO_PROCESS = 10
DOWNLOAD_DIR = Path("sentinel2_complete_tiles")
PROCESSED_DIR = Path("processed_tiles")
TOP_N = 200

# aquí elegís la plataforma: "S2A", "S2B", "S2C" o None para cualquiera
PLATFORM = "S2A"
# ----------------------

def get_cdse_access_token(client_id=CLIENT_ID, client_secret=CLIENT_SECRET):
    token_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
    data = {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
    }
    resp = requests.post(token_url, data=data, timeout=30)
    if resp.status_code == 200:
        print("✓ Access token obtained successfully")
        return resp.json().get('access_token')
    else:
        print(f"✗ Failed to get access token: {resp.status_code}")
        print(resp.text)
        return None

def _parse_sensing_datetime_from_name(name):
    m = re.search(r'_(\d{8}T\d{6})_', name)
    if not m:
        return None
    try:
        return datetime.strptime(m.group(1), "%Y%m%dT%H%M%S")
    except Exception:
        return None

def build_odata_query(aoi, start_date, end_date, platform=None, attempt_sensing_filter=True, top=TOP_N):
    lon_min, lat_min, lon_max, lat_max = aoi
    wkt_polygon = f"POLYGON(({lon_min} {lat_min},{lon_max} {lat_min},{lon_max} {lat_max},{lon_min} {lat_max},{lon_min} {lat_min}))"
    base_url = "https://catalogue.dataspace.copernicus.eu/odata/v1/Products"

    sensing_field_candidates = ["SensingTime", "SensingStart", "SensingStartDate", "SensingStartDateTime"]
    content_filter = f"ContentDate/Start ge {start_date}T00:00:00.000Z and ContentDate/Start le {end_date}T23:59:59.999Z"

    filters = [
        "Collection/Name eq 'SENTINEL-2'",
        "contains(Name,'MSIL2A')",
        f"OData.CSC.Intersects(area=geography'SRID=4326;{wkt_polygon}')",
    ]

    # filtro por plataforma (ej: startswith(Name,'S2A_'))
    if platform:
        # usamos startswith para reducir resultados; si el servicio no soporta startswith, el servidor podría retornar error o ignorarlo
        filters.append(f"startswith(Name,'{platform}_') eq true")

    if attempt_sensing_filter:
        sensing_candidate = sensing_field_candidates[0]
        sensing_filter = f"{sensing_candidate} ge {start_date}T00:00:00.000Z and {sensing_candidate} le {end_date}T23:59:59.999Z"
        filters.append(sensing_filter)
    else:
        filters.append(content_filter)

    filter_string = " and ".join(filters)
    url = f"{base_url}?$filter={filter_string}&$orderby=ContentDate/Start desc&$top={top}"
    return url

def search_sentinel2_products_odata(aoi, start_date, end_date, access_token=None, platform=None, top=TOP_N):
    print("🔍 Searching for Sentinel-2 products via OData...")
    url = build_odata_query(aoi, start_date, end_date, platform=platform, attempt_sensing_filter=True, top=top)
    headers = {}
    if access_token:
        headers['Authorization'] = f'Bearer {access_token}'

    try:
        resp = requests.get(url, headers=headers, timeout=60)
    except Exception as e:
        print("✗ Error contacting OData endpoint:", e)
        return []

    if resp.status_code != 200:
        print("⚠️ OData returned non-200. Intentando fallback usando ContentDate...")
        url = build_odata_query(aoi, start_date, end_date, platform=platform, attempt_sensing_filter=False, top=top)
        try:
            resp = requests.get(url, headers=headers, timeout=60)
        except Exception as e:
            print("✗ Fallback request failed:", e)
            return []
        if resp.status_code != 200:
            print("✗ Fallback OData also failed:", resp.status_code)
            print(resp.text)
            return []

    data = resp.json()
    products = data.get('value', [])
    print(f"✓ OData returned {len(products)} products (before post-filtering)")

    # POST-FILTER por fecha de sensado y plataforma (seguro)
    start_dt = datetime.fromisoformat(start_date).date()
    end_dt = datetime.fromisoformat(end_date).date()

    final_products = []
    for p in products:
        name = p.get('Name', '')
        # 1) comprobar plataforma vía nombre (si PLATFORM fue pedido)
        if platform and not name.startswith(f"{platform}_"):
            # si no coincide, omitir
            continue
        # 2) extraer fecha de sensado desde name
        sensing_dt = _parse_sensing_datetime_from_name(name)
        if sensing_dt:
            if start_dt <= sensing_dt.date() <= end_dt:
                final_products.append(p)
        else:
            # fallback a ContentDate
            cd = p.get('ContentDate', {})
            cd_start = cd.get('Start')
            if cd_start:
                try:
                    cd_dt = datetime.fromisoformat(cd_start.replace('Z','')).date()
                    if start_dt <= cd_dt <= end_dt:
                        final_products.append(p)
                except Exception:
                    pass

    print(f"✓ After name/content-date post-filter: {len(final_products)} products")
    return final_products

def download_sentinel2_product(product_info, access_token, download_dir=DOWNLOAD_DIR, chunk_size=16*1024):
    product_id = product_info['Id']
    product_name = product_info['Name']
    download_dir = Path(download_dir)
    download_dir.mkdir(parents=True, exist_ok=True)

    download_url = f"https://zipper.dataspace.copernicus.eu/odata/v1/Products({product_id})/$value"
    zip_filename = download_dir / f"{product_name}.zip"
    headers = {}
    if access_token:
        headers['Authorization'] = f'Bearer {access_token}'

    if zip_filename.exists():
        print(f"    ✓ File already exists, skipping download: {zip_filename.name}")
        return str(zip_filename)

    print(f"📥 Downloading: {product_name}")
    try:
        with requests.get(download_url, headers=headers, stream=True, timeout=120) as r:
            if r.status_code != 200:
                print(f"    ✗ Download failed: {r.status_code}")
                return None
            total = int(r.headers.get('content-length', 0))
            downloaded = 0
            with open(zip_filename, 'wb') as f:
                for chunk in r.iter_content(chunk_size=chunk_size):
                    if chunk:
                        f.write(chunk)
                        downloaded += len(chunk)
                        if total:
                            if downloaded % (10*1024*1024) < chunk_size:
                                percent = downloaded / total * 100
                                print(f"    Progress: {percent:.1f}% ({downloaded/1024/1024:.1f} MB)")
            print(f"    ✓ Download completed: {downloaded/1024/1024:.1f} MB")
            return str(zip_filename)
    except Exception as e:
        print(f"    ✗ Error downloading: {e}")
        if zip_filename.exists():
            try:
                zip_filename.unlink()
            except:
                pass
        return None

def extract_and_process_safe(zip_file, output_dir=PROCESSED_DIR):
    zip_file = Path(zip_file)
    print(f"📦 Extracting and processing: {zip_file.name}")
    extract_dir = zip_file.with_suffix('')
    output_dir = Path(output_dir)
    extract_dir.mkdir(parents=True, exist_ok=True)
    output_dir.mkdir(parents=True, exist_ok=True)

    try:
        with zipfile.ZipFile(zip_file, 'r') as zf:
            zf.extractall(extract_dir)
    except Exception as e:
        print(f"    ✗ Error extracting zip: {e}")
        return None

    safe_dirs = list(extract_dir.glob("*.SAFE"))
    if not safe_dirs:
        safe_dirs = list(extract_dir.rglob("*.SAFE"))
    if not safe_dirs:
        print("    ✗ No .SAFE directory found")
        return None

    safe_dir = safe_dirs[0]
    safe_name = safe_dir.name
    print(f"    Processing .SAFE: {safe_name}")

    band_pattern = str(safe_dir / "GRANULE" / "*" / "IMG_DATA" / "R10m" / "*_B0?_10m.jp2")
    band_files = glob.glob(band_pattern)
    if not band_files:
        band_files = list(safe_dir.rglob("*_B0?_10m.jp2"))

    rgb_bands = {}
    for bf in band_files:
        if '_B02_' in bf:
            rgb_bands['B02'] = bf
        elif '_B03_' in bf:
            rgb_bands['B03'] = bf
        elif '_B04_' in bf:
            rgb_bands['B04'] = bf

    if len(rgb_bands) != 3:
        print(f"    ✗ Missing RGB bands, found: {list(rgb_bands.keys())}")
        return None

    output_filename = f"{safe_name.replace('.SAFE','')}_RGB_10m.tiff"
    output_path = output_dir / output_filename

    success = create_rgb_composite(rgb_bands, output_path, safe_name)
    if success:
        print(f"    ✓ RGB composite created: {output_filename}")
        return str(output_path)
    else:
        print("    ✗ Failed to create RGB composite")
        return None

def create_rgb_composite(rgb_bands, output_path, safe_name):
    try:
        bands_data = {}
        transform = None
        crs = None
        height = width = None

        for band_key in ['B04', 'B03', 'B02']:
            band_file = rgb_bands.get(band_key)
            with rasterio.open(band_file) as src:
                arr = src.read(1)
                bands_data[band_key] = arr
                if transform is None:
                    transform = src.transform
                    crs = src.crs
                    height, width = src.shape

        rgb_array = np.stack([bands_data['B04'], bands_data['B03'], bands_data['B02']], axis=0)
        rgb_normalized = np.clip(rgb_array * 3.5, 0, 10000).astype(np.uint16)

        output_path = Path(output_path)
        with rasterio.open(
            output_path, 'w',
            driver='GTiff',
            height=height,
            width=width,
            count=3,
            dtype='uint16',
            crs=crs,
            transform=transform,
            compress='lzw',
            tiled=True,
            blockxsize=512,
            blockysize=512
        ) as dst:
            dst.write(rgb_normalized)
            dst.update_tags(
                PRODUCT_NAME=safe_name,
                BANDS='RGB (B04,B03,B02)',
                RESOLUTION='10m',
                PRODUCT_TYPE='SENTINEL2_L2A_COMPLETE_TILE_RGB'
            )

        size_mb = output_path.stat().st_size / (1024*1024)
        print(f"        ✓ RGB composite saved ({size_mb:.1f} MB)")
        return True
    except Exception as e:
        print(f"        ✗ RGB creation error: {e}")
        return False

def download_complete_sentinel2_tiles_odata(aoi, start_date, end_date, platform=None, max_products=MAX_PRODUCTS_TO_PROCESS):
    print("\n" + "="*60)
    print("DOWNLOADING COMPLETE SENTINEL-2 TILES (PLATFORM FILTERING)")
    print("="*60)
    print(f"AOI: {aoi}")
    print(f"Date range: {start_date} to {end_date}")
    print(f"Platform filter: {platform}")
    print("="*60)

    token = get_cdse_access_token()
    if not token:
        print("✗ No access token. Aborting.")
        return

    products = search_sentinel2_products_odata(aoi, start_date, end_date, access_token=token, platform=platform, top=TOP_N)
    if not products:
        print("No products found after post-filter.")
        return

    if max_products:
        products = products[:max_products]

    successful = failed = 0
    for i, p in enumerate(products, 1):
        print(f"\n[{i}/{len(products)}] Processing product: {p.get('Name')}")
        zipf = download_sentinel2_product(p, token)
        if not zipf:
            failed += 1
            continue
        processed = extract_and_process_safe(zipf)
        if processed:
            successful += 1
            print(f"✓ Successfully processed: {Path(processed).name}")
        else:
            failed += 1

    print("\n" + "="*60)
    print("DOWNLOAD FINISHED")
    print("="*60)
    print(f"✓ Successfully processed: {successful}")
    print(f"✗ Failed: {failed}")
    print(f"Processed files in: {PROCESSED_DIR.resolve()}")
    print(f"Raw zips in: {DOWNLOAD_DIR.resolve()}")

if __name__ == "__main__":
    download_complete_sentinel2_tiles_odata(AOI, START_DATE, END_DATE, platform=PLATFORM, max_products=MAX_PRODUCTS_TO_PROCESS)
# Out:
# ============================================================
# DOWNLOADING COMPLETE SENTINEL-2 TILES (PLATFORM FILTERING)
# ============================================================
# AOI: [-62.16, -32.75, -62.04, -32.64]
# Date range: 2022-06-01 to 2022-06-30
# Platform filter: S2A
# ============================================================
# ✓ Access token obtained successfully
# 🔍 Searching for Sentinel-2 products via OData...
# ⚠️ OData returned non-200. Intentando fallback usando ContentDate...
# ✓ OData returned 7 products (before post-filtering)
# ✓ After name/content-date post-filter: 7 products
#
# [1/7] Processing product: S2A_MSIL2A_20220630T135721_N0510_R067_T20HNJ_20240628T174042.SAFE
# 📥 Downloading: S2A_MSIL2A_20220630T135721_N0510_R067_T20HNJ_20240628T174042.SAFE
#     Progress: 1.3% (10.0 MB)
#     Progress: 2.5% (20.0 MB)
#     Progress: 3.8% (30.0 MB)
#     Progress: 5.0% (40.0 MB)
#     Progress: 6.3% (50.0 MB)
#     Progress: 7.5% (60.0 MB)
#     Progress: 8.8% (70.0 MB)
#     Progress: 10.0% (80.0 MB)
#     Progress: 11.3% (90.0 MB)
#     Progress: 12.5% (100.0 MB)
#     Progress: 13.8% (110.0 MB)
#     Progress: 15.0% (120.0 MB)
#     Progress: 16.3% (130.0 MB)
#     Progress: 17.5% (140.0 MB)
#     Progress: 18.8% (150.0 MB)
#     Progress: 20.0% (160.0 MB)
#     Progress: 21.3% (170.0 MB)
#     Progress: 22.5% (180.0 MB)
#     Progress: 23.8% (190.0 MB)
#     Progress: 25.0% (200.0 MB)
#     Progress: 26.3% (210.0 MB)
#     Progress: 27.5% (220.0 MB)
#     Progress: 28.8% (230.0 MB)
#     Progress: 30.0% (240.0 MB)
#     Progress: 31.3% (250.0 MB)
#     Progress: 32.5% (260.0 MB)
#     Progress: 33.8% (270.0 MB)
#     Progress: 35.0% (280.0 MB)
#     Progress: 36.3% (290.0 MB)
#     Progress: 37.5% (300.0 MB)
#     Progress: 38.8% (310.0 MB)
#     Progress: 40.0% (320.0 MB)
#     Progress: 41.3% (330.0 MB)
#     Progress: 42.5% (340.0 MB)
#     Progress: 43.8% (350.0 MB)
#     Progress: 45.0% (360.0 MB)
#     Progress: 46.3% (370.0 MB)
#     Progress: 47.5% (380.0 MB)
#     Progress: 48.8% (390.0 MB)
#     Progress: 50.0% (400.0 MB)
#     Progress: 51.3% (410.0 MB)
#     Progress: 52.5% (420.0 MB)
#     Progress: 53.8% (430.0 MB)
#     Progress: 55.0% (440.0 MB)
#     Progress: 56.3% (450.0 MB)
#     Progress: 57.5% (460.0 MB)
#     Progress: 58.8% (470.0 MB)
#     Progress: 60.0% (480.0 MB)
#     Progress: 61.3% (490.0 MB)
#     Progress: 62.5% (500.0 MB)
#     Progress: 63.8% (510.0 MB)
#     Progress: 65.0% (520.0 MB)
#     Progress: 66.3% (530.0 MB)
#     Progress: 67.5% (540.0 MB)
#     Progress: 68.8% (550.0 MB)
#     Progress: 70.0% (560.0 MB)
#     Progress: 71.3% (570.0 MB)
#     Progress: 72.5% (580.0 MB)
#     Progress: 73.8% (590.0 MB)
#     Progress: 75.0% (600.0 MB)
#     Progress: 76.3% (610.0 MB)
#     Progress: 77.5% (620.0 MB)
#     Progress: 78.8% (630.0 MB)
#     Progress: 80.0% (640.0 MB)
#     Progress: 81.3% (650.0 MB)
#     Progress: 82.5% (660.0 MB)
#     Progress: 83.8% (670.0 MB)
#     Progress: 85.0% (680.0 MB)
#     Progress: 86.3% (690.0 MB)
#     Progress: 87.5% (700.0 MB)
#     Progress: 88.8% (710.0 MB)
#     Progress: 90.0% (720.0 MB)
#     Progress: 91.3% (730.0 MB)
#     Progress: 92.5% (740.0 MB)
#     Progress: 93.8% (750.0 MB)
#     Progress: 95.0% (760.0 MB)
#     Progress: 96.3% (770.0 MB)
#     Progress: 97.5% (780.0 MB)
#     Progress: 98.8% (790.0 MB)
#     ✓ Download completed: 799.7 MB
# 📦 Extracting and processing: S2A_MSIL2A_20220630T135721_N0510_R067_T20HNJ_20240628T174042.SAFE.zip
#     Processing .SAFE: S2A_MSIL2A_20220630T135721_N0510_R067_T20HNJ_20240628T174042.SAFE
#         ✓ RGB composite saved (434.1 MB)
#     ✓ RGB composite created: S2A_MSIL2A_20220630T135721_N0510_R067_T20HNJ_20240628T174042_RGB_10m.tiff
# ✓ Successfully processed: S2A_MSIL2A_20220630T135721_N0510_R067_T20HNJ_20240628T174042_RGB_10m.tiff
#
# [2/7] Processing product: S2A_MSIL2A_20220623T140721_N0510_R110_T20HNJ_20240621T234441.SAFE
# 📥 Downloading: S2A_MSIL2A_20220623T140721_N0510_R110_T20HNJ_20240621T234441.SAFE
#     Progress: 1.0% (10.0 MB)
#     Progress: 2.1% (20.0 MB)
#     Progress: 3.1% (30.0 MB)
#     Progress: 4.1% (40.0 MB)
#     Progress: 5.2% (50.0 MB)
#     Progress: 6.2% (60.0 MB)
#     Progress: 7.2% (70.0 MB)
#     Progress: 8.3% (80.0 MB)
#     Progress: 9.3% (90.0 MB)
#     Progress: 10.3% (100.0 MB)
#     Progress: 11.4% (110.0 MB)
#     Progress: 12.4% (120.0 MB)
#     Progress: 13.5% (130.0 MB)
#     Progress: 14.5% (140.0 MB)
#     Progress: 15.5% (150.0 MB)
#     Progress: 16.6% (160.0 MB)
#     Progress: 17.6% (170.0 MB)
#     Progress: 18.6% (180.0 MB)
#     Progress: 19.7% (190.0 MB)
#     Progress: 20.7% (200.0 MB)
#     Progress: 21.7% (210.0 MB)
#     Progress: 22.8% (220.0 MB)
#     Progress: 23.8% (230.0 MB)
#     Progress: 24.8% (240.0 MB)
#     Progress: 25.9% (250.0 MB)
#     Progress: 26.9% (260.0 MB)
#     Progress: 27.9% (270.0 MB)
#     Progress: 29.0% (280.0 MB)
#     Progress: 30.0% (290.0 MB)
#     Progress: 31.0% (300.0 MB)
#     Progress: 32.1% (310.0 MB)
#     Progress: 33.1% (320.0 MB)
#     Progress: 34.2% (330.0 MB)
#     Progress: 35.2% (340.0 MB)
#     Progress: 36.2% (350.0 MB)
#     Progress: 37.3% (360.0 MB)
#     Progress: 38.3% (370.0 MB)
#     Progress: 39.3% (380.0 MB)
#     Progress: 40.4% (390.0 MB)
#     Progress: 41.4% (400.0 MB)
#     Progress: 42.4% (410.0 MB)
#     Progress: 43.5% (420.0 MB)
#     Progress: 44.5% (430.0 MB)
#     Progress: 45.5% (440.0 MB)
#     Progress: 46.6% (450.0 MB)
#     Progress: 47.6% (460.0 MB)
#     Progress: 48.6% (470.0 MB)
#     Progress: 49.7% (480.0 MB)
#     Progress: 50.7% (490.0 MB)
#     Progress: 51.7% (500.0 MB)
#     Progress: 52.8% (510.0 MB)
#     Progress: 53.8% (520.0 MB)
#     Progress: 54.9% (530.0 MB)
#     Progress: 55.9% (540.0 MB)
#     Progress: 56.9% (550.0 MB)
#     Progress: 58.0% (560.0 MB)
#     Progress: 59.0% (570.0 MB)
#     Progress: 60.0% (580.0 MB)
#     Progress: 61.1% (590.0 MB)
#     Progress: 62.1% (600.0 MB)
#     Progress: 63.1% (610.0 MB)
#     Progress: 64.2% (620.0 MB)
#     Progress: 65.2% (630.0 MB)
#     Progress: 66.2% (640.0 MB)
#     Progress: 67.3% (650.0 MB)
#     Progress: 68.3% (660.0 MB)
#     Progress: 69.3% (670.0 MB)
#     Progress: 70.4% (680.0 MB)
#     Progress: 71.4% (690.0 MB)
#     Progress: 72.4% (700.0 MB)
#     Progress: 73.5% (710.0 MB)
#     Progress: 74.5% (720.0 MB)
#     Progress: 75.6% (730.0 MB)
#     Progress: 76.6% (740.0 MB)
#     Progress: 77.6% (750.0 MB)
#     Progress: 78.7% (760.0 MB)
#     Progress: 79.7% (770.0 MB)
#     Progress: 80.7% (780.0 MB)
#     Progress: 81.8% (790.0 MB)
#     Progress: 82.8% (800.0 MB)
#     Progress: 83.8% (810.0 MB)
#     Progress: 84.9% (820.0 MB)
#     Progress: 85.9% (830.0 MB)
#     Progress: 86.9% (840.0 MB)
#     Progress: 88.0% (850.0 MB)
#     Progress: 89.0% (860.0 MB)
#     Progress: 90.0% (870.0 MB)
#     Progress: 91.1% (880.0 MB)
#     Progress: 92.1% (890.0 MB)
#     Progress: 93.1% (900.0 MB)
#     Progress: 94.2% (910.0 MB)
#     Progress: 95.2% (920.0 MB)
#     Progress: 96.3% (930.0 MB)
#     Progress: 97.3% (940.0 MB)
#     Progress: 98.3% (950.0 MB)
#     Progress: 99.4% (960.0 MB)
#     ✓ Download completed: 966.2 MB
# 📦 Extracting and processing: S2A_MSIL2A_20220623T140721_N0510_R110_T20HNJ_20240621T234441.SAFE.zip
#     Processing .SAFE: S2A_MSIL2A_20220623T140721_N0510_R110_T20HNJ_20240621T234441.SAFE
#         ✓ RGB composite saved (529.2 MB)
#     ✓ RGB composite created: S2A_MSIL2A_20220623T140721_N0510_R110_T20HNJ_20240621T234441_RGB_10m.tiff
# ✓ Successfully processed: S2A_MSIL2A_20220623T140721_N0510_R110_T20HNJ_20240621T234441_RGB_10m.tiff
#
# [3/7] Processing product: S2A_MSIL2A_20220620T135721_N0510_R067_T20HNJ_20240619T171640.SAFE
# 📥 Downloading: S2A_MSIL2A_20220620T135721_N0510_R067_T20HNJ_20240619T171640.SAFE
#     Progress: 1.4% (10.0 MB)
#     Progress: 2.8% (20.0 MB)
#     Progress: 4.1% (30.0 MB)
#     Progress: 5.5% (40.0 MB)
#     Progress: 6.9% (50.0 MB)
#     Progress: 8.3% (60.0 MB)
#     Progress: 9.6% (70.0 MB)
#     Progress: 11.0% (80.0 MB)
#     Progress: 12.4% (90.0 MB)
#     Progress: 13.8% (100.0 MB)
#     Progress: 15.1% (110.0 MB)
#     Progress: 16.5% (120.0 MB)
#     Progress: 17.9% (130.0 MB)
#     Progress: 19.3% (140.0 MB)
#     Progress: 20.7% (150.0 MB)
#     Progress: 22.0% (160.0 MB)
#     Progress: 23.4% (170.0 MB)
#     Progress: 24.8% (180.0 MB)
#     Progress: 26.2% (190.0 MB)
#     Progress: 27.5% (200.0 MB)
#     Progress: 28.9% (210.0 MB)
#     Progress: 30.3% (220.0 MB)
#     Progress: 31.7% (230.0 MB)
#     Progress: 33.0% (240.0 MB)
#     Progress: 34.4% (250.0 MB)
#     Progress: 35.8% (260.0 MB)
#     Progress: 37.2% (270.0 MB)
#     Progress: 38.5% (280.0 MB)
#     Progress: 39.9% (290.0 MB)
#     Progress: 41.3% (300.0 MB)
#     Progress: 42.7% (310.0 MB)
#     Progress: 44.1% (320.0 MB)
#     Progress: 45.4% (330.0 MB)
#     Progress: 46.8% (340.0 MB)
#     Progress: 48.2% (350.0 MB)
#     Progress: 49.6% (360.0 MB)
#     Progress: 50.9% (370.0 MB)
#     Progress: 52.3% (380.0 MB)
#     Progress: 53.7% (390.0 MB)
#     Progress: 55.1% (400.0 MB)
#     Progress: 56.4% (410.0 MB)
#     Progress: 57.8% (420.0 MB)
#     Progress: 59.2% (430.0 MB)
#     Progress: 60.6% (440.0 MB)
#     Progress: 62.0% (450.0 MB)
#     Progress: 63.3% (460.0 MB)
#     Progress: 64.7% (470.0 MB)
#     Progress: 66.1% (480.0 MB)
#     Progress: 67.5% (490.0 MB)
#     Progress: 68.8% (500.0 MB)
#     Progress: 70.2% (510.0 MB)
#     Progress: 71.6% (520.0 MB)
#     Progress: 73.0% (530.0 MB)
#     Progress: 74.3% (540.0 MB)
#     Progress: 75.7% (550.0 MB)
#     Progress: 77.1% (560.0 MB)
#     Progress: 78.5% (570.0 MB)
#     Progress: 79.9% (580.0 MB)
#     Progress: 81.2% (590.0 MB)
#     Progress: 82.6% (600.0 MB)
#     Progress: 84.0% (610.0 MB)
#     Progress: 85.4% (620.0 MB)
#     Progress: 86.7% (630.0 MB)
#     Progress: 88.1% (640.0 MB)
#     Progress: 89.5% (650.0 MB)
#     Progress: 90.9% (660.0 MB)
#     Progress: 92.2% (670.0 MB)
#     Progress: 93.6% (680.0 MB)
#     Progress: 95.0% (690.0 MB)
#     Progress: 96.4% (700.0 MB)
#     Progress: 97.8% (710.0 MB)
#     Progress: 99.1% (720.0 MB)
#     ✓ Download completed: 726.3 MB
# 📦 Extracting and processing: S2A_MSIL2A_20220620T135721_N0510_R067_T20HNJ_20240619T171640.SAFE.zip
#     Processing .SAFE: S2A_MSIL2A_20220620T135721_N0510_R067_T20HNJ_20240619T171640.SAFE
#         ✓ RGB composite saved (293.3 MB)
#     ✓ RGB composite created: S2A_MSIL2A_20220620T135721_N0510_R067_T20HNJ_20240619T171640_RGB_10m.tiff
# ✓ Successfully processed: S2A_MSIL2A_20220620T135721_N0510_R067_T20HNJ_20240619T171640_RGB_10m.tiff
#
# [4/7] Processing product: S2A_MSIL2A_20220613T140721_N0510_R110_T20HNJ_20240628T061725.SAFE
# 📥 Downloading: S2A_MSIL2A_20220613T140721_N0510_R110_T20HNJ_20240628T061725.SAFE
#     Progress: 1.0% (10.0 MB)
#     Progress: 2.1% (20.0 MB)
#     Progress: 3.1% (30.0 MB)
#     Progress: 4.1% (40.0 MB)
#     Progress: 5.1% (50.0 MB)
#     Progress: 6.2% (60.0 MB)
#     Progress: 7.2% (70.0 MB)
#     Progress: 8.2% (80.0 MB)
#     Progress: 9.2% (90.0 MB)
#     Progress: 10.3% (100.0 MB)
#     Progress: 11.3% (110.0 MB)
#     Progress: 12.3% (120.0 MB)
#     Progress: 13.3% (130.0 MB)
#     Progress: 14.4% (140.0 MB)
#     Progress: 15.4% (150.0 MB)
#     Progress: 16.4% (160.0 MB)
#     Progress: 17.4% (170.0 MB)
#     Progress: 18.5% (180.0 MB)
#     Progress: 19.5% (190.0 MB)
#     Progress: 20.5% (200.0 MB)
#     Progress: 21.5% (210.0 MB)
#     Progress: 22.6% (220.0 MB)
#     Progress: 23.6% (230.0 MB)
#     Progress: 24.6% (240.0 MB)
#     Progress: 25.6% (250.0 MB)
#     Progress: 26.7% (260.0 MB)
#     Progress: 27.7% (270.0 MB)
#     Progress: 28.7% (280.0 MB)
#     Progress: 29.7% (290.0 MB)
#     Progress: 30.8% (300.0 MB)
#     Progress: 31.8% (310.0 MB)
#     Progress: 32.8% (320.0 MB)
#     Progress: 33.8% (330.0 MB)
#     Progress: 34.9% (340.0 MB)
#     Progress: 35.9% (350.0 MB)
#     Progress: 36.9% (360.0 MB)
#     Progress: 37.9% (370.0 MB)
#     Progress: 39.0% (380.0 MB)
#     Progress: 40.0% (390.0 MB)
#     Progress: 41.0% (400.0 MB)
#     Progress: 42.0% (410.0 MB)
#     Progress: 43.1% (420.0 MB)
#     Progress: 44.1% (430.0 MB)
#     Progress: 45.1% (440.0 MB)
#     Progress: 46.1% (450.0 MB)
#     Progress: 47.2% (460.0 MB)
#     Progress: 48.2% (470.0 MB)
#     Progress: 49.2% (480.0 MB)
#     Progress: 50.2% (490.0 MB)
#     Progress: 51.3% (500.0 MB)
#     Progress: 52.3% (510.0 MB)
#     Progress: 53.3% (520.0 MB)
#     Progress: 54.3% (530.0 MB)
#     Progress: 55.4% (540.0 MB)
#     Progress: 56.4% (550.0 MB)
#     Progress: 57.4% (560.0 MB)
#     Progress: 58.4% (570.0 MB)
#     Progress: 59.5% (580.0 MB)
#     Progress: 60.5% (590.0 MB)
#     Progress: 61.5% (600.0 MB)
#     Progress: 62.5% (610.0 MB)
#     Progress: 63.6% (620.0 MB)
#     Progress: 64.6% (630.0 MB)
#     Progress: 65.6% (640.0 MB)
#     Progress: 66.7% (650.0 MB)
#     Progress: 67.7% (660.0 MB)
#     Progress: 68.7% (670.0 MB)
#     Progress: 69.7% (680.0 MB)
#     Progress: 70.8% (690.0 MB)
#     Progress: 71.8% (700.0 MB)
#     Progress: 72.8% (710.0 MB)
#     Progress: 73.8% (720.0 MB)
#     Progress: 74.9% (730.0 MB)
#     Progress: 75.9% (740.0 MB)
#     Progress: 76.9% (750.0 MB)
#     Progress: 77.9% (760.0 MB)
#     Progress: 79.0% (770.0 MB)
#     Progress: 80.0% (780.0 MB)
#     Progress: 81.0% (790.0 MB)
#     Progress: 82.0% (800.0 MB)
#     Progress: 83.1% (810.0 MB)
#     Progress: 84.1% (820.0 MB)
#     Progress: 85.1% (830.0 MB)
#     Progress: 86.1% (840.0 MB)
#     Progress: 87.2% (850.0 MB)
#     Progress: 88.2% (860.0 MB)
#     Progress: 89.2% (870.0 MB)
#     Progress: 90.2% (880.0 MB)
#     Progress: 91.3% (890.0 MB)
#     Progress: 92.3% (900.0 MB)
#     Progress: 93.3% (910.0 MB)
#     Progress: 94.3% (920.0 MB)
#     Progress: 95.4% (930.0 MB)
#     Progress: 96.4% (940.0 MB)
#     Progress: 97.4% (950.0 MB)
#     Progress: 98.4% (960.0 MB)
#     Progress: 99.5% (970.0 MB)
#     ✓ Download completed: 975.2 MB
# 📦 Extracting and processing: S2A_MSIL2A_20220613T140721_N0510_R110_T20HNJ_20240628T061725.SAFE.zip
#     Processing .SAFE: S2A_MSIL2A_20220613T140721_N0510_R110_T20HNJ_20240628T061725.SAFE
#         ✓ RGB composite saved (552.8 MB)
#     ✓ RGB composite created: S2A_MSIL2A_20220613T140721_N0510_R110_T20HNJ_20240628T061725_RGB_10m.tiff
# ✓ Successfully processed: S2A_MSIL2A_20220613T140721_N0510_R110_T20HNJ_20240628T061725_RGB_10m.tiff
#
# [5/7] Processing product: S2A_MSIL2A_20220613T140721_N0400_R110_T20HNJ_20220613T233208.SAFE
# 📥 Downloading: S2A_MSIL2A_20220613T140721_N0400_R110_T20HNJ_20220613T233208.SAFE
#     Progress: 1.0% (10.0 MB)
#     Progress: 2.1% (20.0 MB)
#     Progress: 3.1% (30.0 MB)
#     Progress: 4.1% (40.0 MB)
#     Progress: 5.1% (50.0 MB)
#     Progress: 6.2% (60.0 MB)
#     Progress: 7.2% (70.0 MB)
#     Progress: 8.2% (80.0 MB)
#     Progress: 9.2% (90.0 MB)
#     Progress: 10.3% (100.0 MB)
#     Progress: 11.3% (110.0 MB)
#     Progress: 12.3% (120.0 MB)
#     Progress: 13.4% (130.0 MB)
#     Progress: 14.4% (140.0 MB)
#     Progress: 15.4% (150.0 MB)
#     Progress: 16.4% (160.0 MB)
#     Progress: 17.5% (170.0 MB)
#     Progress: 18.5% (180.0 MB)
#     Progress: 19.5% (190.0 MB)
#     Progress: 20.5% (200.0 MB)
#     Progress: 21.6% (210.0 MB)
#     Progress: 22.6% (220.0 MB)
#     Progress: 23.6% (230.0 MB)
#     Progress: 24.7% (240.0 MB)
#     Progress: 25.7% (250.0 MB)
#     Progress: 26.7% (260.0 MB)
#     Progress: 27.7% (270.0 MB)
#     Progress: 28.8% (280.0 MB)
#     Progress: 29.8% (290.0 MB)
#     Progress: 30.8% (300.0 MB)
#     Progress: 31.8% (310.0 MB)
#     Progress: 32.9% (320.0 MB)
#     Progress: 33.9% (330.0 MB)
#     Progress: 34.9% (340.0 MB)
#     Progress: 36.0% (350.0 MB)
#     Progress: 37.0% (360.0 MB)
#     Progress: 38.0% (370.0 MB)
#     Progress: 39.0% (380.0 MB)
#     Progress: 40.1% (390.0 MB)
#     Progress: 41.1% (400.0 MB)
#     Progress: 42.1% (410.0 MB)
#     Progress: 43.1% (420.0 MB)
#     Progress: 44.2% (430.0 MB)
#     Progress: 45.2% (440.0 MB)
#     Progress: 46.2% (450.0 MB)
#     Progress: 47.3% (460.0 MB)
#     Progress: 48.3% (470.0 MB)
#     Progress: 49.3% (480.0 MB)
#     Progress: 50.3% (490.0 MB)
#     Progress: 51.4% (500.0 MB)
#     Progress: 52.4% (510.0 MB)
#     Progress: 53.4% (520.0 MB)
#     Progress: 54.4% (530.0 MB)
#     Progress: 55.5% (540.0 MB)
#     Progress: 56.5% (550.0 MB)
#     Progress: 57.5% (560.0 MB)
#     Progress: 58.6% (570.0 MB)
#     Progress: 59.6% (580.0 MB)
#     Progress: 60.6% (590.0 MB)
#     Progress: 61.6% (600.0 MB)
#     Progress: 62.7% (610.0 MB)
#     Progress: 63.7% (620.0 MB)
#     Progress: 64.7% (630.0 MB)
#     Progress: 65.7% (640.0 MB)
#     Progress: 66.8% (650.0 MB)
#     Progress: 67.8% (660.0 MB)
#     Progress: 68.8% (670.0 MB)
#     Progress: 69.9% (680.0 MB)
#     Progress: 70.9% (690.0 MB)
#     Progress: 71.9% (700.0 MB)
#     Progress: 72.9% (710.0 MB)
#     Progress: 74.0% (720.0 MB)
#     Progress: 75.0% (730.0 MB)
#     Progress: 76.0% (740.0 MB)
#     Progress: 77.0% (750.0 MB)
#     Progress: 78.1% (760.0 MB)
#     Progress: 79.1% (770.0 MB)
#     Progress: 80.1% (780.0 MB)
#     Progress: 81.2% (790.0 MB)
#     Progress: 82.2% (800.0 MB)
#     Progress: 83.2% (810.0 MB)
#     Progress: 84.2% (820.0 MB)
#     Progress: 85.3% (830.0 MB)
#     Progress: 86.3% (840.0 MB)
#     Progress: 87.3% (850.0 MB)
#     Progress: 88.3% (860.0 MB)
#     Progress: 89.4% (870.0 MB)
#     Progress: 90.4% (880.0 MB)
#     Progress: 91.4% (890.0 MB)
#     Progress: 92.5% (900.0 MB)
#     Progress: 93.5% (910.0 MB)
#     Progress: 94.5% (920.0 MB)
#     Progress: 95.5% (930.0 MB)
#     Progress: 96.6% (940.0 MB)
#     Progress: 97.6% (950.0 MB)
#     Progress: 98.6% (960.0 MB)
#     Progress: 99.6% (970.0 MB)
#     ✓ Download completed: 973.4 MB
# 📦 Extracting and processing: S2A_MSIL2A_20220613T140721_N0400_R110_T20HNJ_20220613T233208.SAFE.zip
#     Processing .SAFE: S2A_MSIL2A_20220613T140721_N0400_R110_T20HNJ_20220613T233208.SAFE
#         ✓ RGB composite saved (552.7 MB)
#     ✓ RGB composite created: S2A_MSIL2A_20220613T140721_N0400_R110_T20HNJ_20220613T233208_RGB_10m.tiff
# ✓ Successfully processed: S2A_MSIL2A_20220613T140721_N0400_R110_T20HNJ_20220613T233208_RGB_10m.tiff
#
# [6/7] Processing product: S2A_MSIL2A_20220610T135711_N0510_R067_T20HNJ_20240702T005253.SAFE
# 📥 Downloading: S2A_MSIL2A_20220610T135711_N0510_R067_T20HNJ_20240702T005253.SAFE
#     ✗ Download failed: 401
#
# [7/7] Processing product: S2A_MSIL2A_20220603T141051_N0510_R110_T20HNJ_20240715T013835.SAFE
# 📥 Downloading: S2A_MSIL2A_20220603T141051_N0510_R110_T20HNJ_20240715T013835.SAFE
#     ✗ Download failed: 401
#
# ============================================================
# DOWNLOAD FINISHED
# ============================================================
# ✓ Successfully processed: 5
# ✗ Failed: 2
# Processed files in: C:\Users\m\Documents\Tesis_Silos\Silos_FR_MCDtf\Nootebooks\processed_tiles
# Raw zips in: C:\Users\m\Documents\Tesis_Silos\Silos_FR_MCDtf\Nootebooks\sentinel2_complete_tiles

# %% [markdown]
# ### Public AWS S3 bucket

# %%
# sentinel_download_from_aws_structured.py
import os
import boto3
from botocore import UNSIGNED
from botocore.config import Config
from datetime import datetime
from tqdm import tqdm

# CONFIG
OUT_DIR = './s2_aws_downloads_structured'
os.makedirs(OUT_DIR, exist_ok=True)
tile = "20HNH"   # Tile MGRS
year = 2024
start = datetime(year, 6, 1)
end = datetime(year, 8, 31, 23, 59, 59)

# AWS bucket público
BUCKET = 'sentinel-s2-l2a'
s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))

def tile_to_prefix(tile_code):
    utm = tile_code[:2]
    latband = tile_code[2]
    sq = tile_code[3:]
    return f"tiles/{utm}/{latband}/{sq}/"

prefix = tile_to_prefix(tile)
print("Usando prefijo S3:", prefix)

# Listar objetos
paginator = s3.get_paginator('list_objects_v2')
pages = paginator.paginate(Bucket=BUCKET, Prefix=prefix, RequestPayer='requester')

keys = []
for page in pages:
    for obj in page.get('Contents', []):
        key = obj['Key']
        # Estructura: tiles/20/H/NJ/YYYY/MM/DD/HHMMSS/...
        parts = key.split('/')
        try:
            yyyy = int(parts[4]); mm = int(parts[5]); dd = int(parts[6])
            dt = datetime(yyyy, mm, dd)
            if start.date() <= dt.date() <= end.date():
                keys.append(key)
        except Exception:
            pass

print(f"Encontrados {len(keys)} objetos para el tile {tile} en el rango de fechas.")

# Descargar manteniendo estructura
for key in tqdm(keys):
    # Ejemplo key:
    # tiles/20/H/NJ/2024/06/01/0/L2A_T20HNJ_20240601T142721/.../B02.jp2
    local_path = os.path.join(OUT_DIR, key)  # Mantiene estructura completa
    local_dir = os.path.dirname(local_path)
    os.makedirs(local_dir, exist_ok=True)

    try:
        s3.download_file(BUCKET, key, local_path, ExtraArgs={'RequestPayer': 'requester'})
    except Exception as e:
        print(f"Error descargando {key}: {e}")

print("✅ Descarga AWS finalizada. Revisa:", OUT_DIR)
# Out:
# Usando prefijo S3: tiles/20/H/NH/
# Encontrados 2886 objetos para el tile 20HNH en el rango de fechas.
# 100%|██████████| 2886/2886 [1:49:30<00:00,  2.28s/it]
# ✅ Descarga AWS finalizada. Revisa: ./s2_aws_downloads_structured
